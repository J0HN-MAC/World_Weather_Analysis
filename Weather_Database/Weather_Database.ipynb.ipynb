# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 755

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]    
        city_current_description = city_weather["weather"][0]["description"]    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_current_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | ponta do sol
# Processing Record 3 of Set 1 | guayaramerin
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | east london
# Processing Record 7 of Set 1 | la ronge
# Processing Record 8 of Set 1 | pangai
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | andselv
# City not found. Skipping...
# Processing Record 13 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | coruripe
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | sakaiminato
# Processing Record 20 of Set 1 | mahebourg
# Processing Record 21 of Set 1 | sitka
# Processing Record 22 of Set 1 | meulaboh
# Processing Record 23 of Set 1 | anadyr
# Processing Record 24 of Set 1 | mayumba
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | souillac
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | butaritari
# Processing Record 30 of Set 1 | komsomolskiy
# Processing Record 31 of Set 1 | touros
# Processing Record 32 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 1 | saint anthony
# Processing Record 34 of Set 1 | nanortalik
# Processing Record 35 of Set 1 | micheweni
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | cartagena
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | coromandel
# Processing Record 40 of Set 1 | hay river
# Processing Record 41 of Set 1 | longyearbyen
# Processing Record 42 of Set 1 | khatanga
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | hilo
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | bani
# Processing Record 47 of Set 1 | new richmond
# Processing Record 48 of Set 1 | mitu
# Processing Record 49 of Set 1 | surab
# Processing Record 50 of Set 1 | mareeba
# Processing Record 1 of Set 2 | matagami
# Processing Record 2 of Set 2 | paamiut
# Processing Record 3 of Set 2 | ouango
# Processing Record 4 of Set 2 | scottsbluff
# Processing Record 5 of Set 2 | bandarbeyla
# Processing Record 6 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | hearst
# Processing Record 9 of Set 2 | provideniya
# Processing Record 10 of Set 2 | east stroudsburg
# Processing Record 11 of Set 2 | kahului
# Processing Record 12 of Set 2 | georgetown
# Processing Record 13 of Set 2 | mataura
# Processing Record 14 of Set 2 | rocha
# Processing Record 15 of Set 2 | tuktoyaktuk
# Processing Record 16 of Set 2 | sao filipe
# Processing Record 17 of Set 2 | lebu
# Processing Record 18 of Set 2 | jamestown
# Processing Record 19 of Set 2 | kuchera
# Processing Record 20 of Set 2 | morris
# Processing Record 21 of Set 2 | novoalekseyevskaya
# Processing Record 22 of Set 2 | kruisfontein
# Processing Record 23 of Set 2 | putina
# Processing Record 24 of Set 2 | codrington
# Processing Record 25 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 2 | dmitrov
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | canyon
# Processing Record 29 of Set 2 | coquimbo
# Processing Record 30 of Set 2 | torbat-e jam
# Processing Record 31 of Set 2 | barrow
# Processing Record 32 of Set 2 | hobart
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | torbay
# Processing Record 35 of Set 2 | lianoveryion
# City not found. Skipping...
# Processing Record 36 of Set 2 | cajamarca
# Processing Record 37 of Set 2 | qaanaaq
# Processing Record 38 of Set 2 | hasaki
# Processing Record 39 of Set 2 | buraydah
# Processing Record 40 of Set 2 | raga
# Processing Record 41 of Set 2 | kodinar
# Processing Record 42 of Set 2 | qasigiannguit
# Processing Record 43 of Set 2 | merrill
# Processing Record 44 of Set 2 | cururupu
# Processing Record 45 of Set 2 | finnsnes
# Processing Record 46 of Set 2 | dudinka
# Processing Record 47 of Set 2 | thompson
# Processing Record 48 of Set 2 | joao camara
# Processing Record 49 of Set 2 | neuquen
# Processing Record 50 of Set 2 | yulara
# Processing Record 1 of Set 3 | port elizabeth
# Processing Record 2 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 3 of Set 3 | a
# City not found. Skipping...
# Processing Record 4 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 3 | olinda
# Processing Record 6 of Set 3 | bambous virieux
# Processing Record 7 of Set 3 | zyryanka
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | winnemucca
# Processing Record 10 of Set 3 | senador jose porfirio
# Processing Record 11 of Set 3 | gwadar
# Processing Record 12 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 3 | san patricio
# Processing Record 14 of Set 3 | kilindoni
# Processing Record 15 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 17 of Set 3 | veraval
# Processing Record 18 of Set 3 | ribeira grande
# Processing Record 19 of Set 3 | yellowknife
# Processing Record 20 of Set 3 | nsanje
# Processing Record 21 of Set 3 | panama city
# Processing Record 22 of Set 3 | olafsvik
# Processing Record 23 of Set 3 | ahuimanu
# Processing Record 24 of Set 3 | port blair
# Processing Record 25 of Set 3 | cartagena del chaira
# Processing Record 26 of Set 3 | pangnirtung
# Processing Record 27 of Set 3 | atuona
# Processing Record 28 of Set 3 | chuy
# Processing Record 29 of Set 3 | guerrero negro
# Processing Record 30 of Set 3 | okhotsk
# Processing Record 31 of Set 3 | sokolo
# Processing Record 32 of Set 3 | chara
# Processing Record 33 of Set 3 | saskylakh
# Processing Record 34 of Set 3 | high prairie
# Processing Record 35 of Set 3 | russell
# Processing Record 36 of Set 3 | waiuku
# Processing Record 37 of Set 3 | castro
# Processing Record 38 of Set 3 | isangel
# Processing Record 39 of Set 3 | kortkeros
# Processing Record 40 of Set 3 | nakusp
# Processing Record 41 of Set 3 | harrisburg
# Processing Record 42 of Set 3 | tuatapere
# Processing Record 43 of Set 3 | panaba
# Processing Record 44 of Set 3 | alamogordo
# Processing Record 45 of Set 3 | auki
# Processing Record 46 of Set 3 | namatanai
# Processing Record 47 of Set 3 | adeje
# Processing Record 48 of Set 3 | severo-kurilsk
# Processing Record 49 of Set 3 | new norfolk
# Processing Record 50 of Set 3 | klaksvik
# Processing Record 1 of Set 4 | upplands-vasby
# City not found. Skipping...
# Processing Record 2 of Set 4 | camopi
# Processing Record 3 of Set 4 | okha
# Processing Record 4 of Set 4 | isabela
# Processing Record 5 of Set 4 | juegang
# Processing Record 6 of Set 4 | port lincoln
# Processing Record 7 of Set 4 | geraldton
# Processing Record 8 of Set 4 | yeppoon
# Processing Record 9 of Set 4 | alto araguaia
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | koumac
# Processing Record 12 of Set 4 | makakilo city
# Processing Record 13 of Set 4 | catumbela
# Processing Record 14 of Set 4 | te anau
# Processing Record 15 of Set 4 | narsaq
# Processing Record 16 of Set 4 | ilulissat
# Processing Record 17 of Set 4 | norman wells
# Processing Record 18 of Set 4 | beringovskiy
# Processing Record 19 of Set 4 | nara
# Processing Record 20 of Set 4 | lavrentiya
# Processing Record 21 of Set 4 | kieta
# Processing Record 22 of Set 4 | berbera
# Processing Record 23 of Set 4 | esperance
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | kaitangata
# Processing Record 26 of Set 4 | adrar
# Processing Record 27 of Set 4 | ardmore
# Processing Record 28 of Set 4 | sorong
# Processing Record 29 of Set 4 | progreso
# Processing Record 30 of Set 4 | bull savanna
# Processing Record 31 of Set 4 | talnakh
# Processing Record 32 of Set 4 | vao
# Processing Record 33 of Set 4 | luanda
# Processing Record 34 of Set 4 | sangar
# Processing Record 35 of Set 4 | yuzawa
# Processing Record 36 of Set 4 | sola
# Processing Record 37 of Set 4 | umm bab
# Processing Record 38 of Set 4 | las cruces
# Processing Record 39 of Set 4 | caravelas
# Processing Record 40 of Set 4 | ambilobe
# Processing Record 41 of Set 4 | victoria
# Processing Record 42 of Set 4 | liku
# Processing Record 43 of Set 4 | bako
# Processing Record 44 of Set 4 | bruntal
# Processing Record 45 of Set 4 | supe
# Processing Record 46 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 4 | puerto escondido
# Processing Record 48 of Set 4 | puerto narino
# Processing Record 49 of Set 4 | ghanzi
# Processing Record 50 of Set 4 | hobyo
# Processing Record 1 of Set 5 | flinders
# Processing Record 2 of Set 5 | shingu
# Processing Record 3 of Set 5 | jizan
# Processing Record 4 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 5 | peru
# Processing Record 6 of Set 5 | sept-iles
# Processing Record 7 of Set 5 | sumenep
# Processing Record 8 of Set 5 | kidal
# Processing Record 9 of Set 5 | upernavik
# Processing Record 10 of Set 5 | coro
# Processing Record 11 of Set 5 | semey
# Processing Record 12 of Set 5 | san quintin
# Processing Record 13 of Set 5 | marystown
# Processing Record 14 of Set 5 | muncar
# Processing Record 15 of Set 5 | bara
# Processing Record 16 of Set 5 | lufilufi
# Processing Record 17 of Set 5 | zhangzhou
# Processing Record 18 of Set 5 | piotrkow trybunalski
# Processing Record 19 of Set 5 | pitelino
# Processing Record 20 of Set 5 | antalaha
# Processing Record 21 of Set 5 | orotukan
# Processing Record 22 of Set 5 | maloy
# Processing Record 23 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 5 | lithgow
# Processing Record 25 of Set 5 | luancheng
# Processing Record 26 of Set 5 | morondava
# Processing Record 27 of Set 5 | othaya
# Processing Record 28 of Set 5 | dicabisagan
# Processing Record 29 of Set 5 | pangody
# Processing Record 30 of Set 5 | solnechnyy
# Processing Record 31 of Set 5 | siavonga
# Processing Record 32 of Set 5 | avarua
# Processing Record 33 of Set 5 | aksu
# Processing Record 34 of Set 5 | poum
# Processing Record 35 of Set 5 | bathsheba
# Processing Record 36 of Set 5 | samarai
# Processing Record 37 of Set 5 | constitucion
# Processing Record 38 of Set 5 | hami
# Processing Record 39 of Set 5 | kholodnyy
# Processing Record 40 of Set 5 | los llanos de aridane
# Processing Record 41 of Set 5 | honiara
# Processing Record 42 of Set 5 | sao francisco de assis
# Processing Record 43 of Set 5 | avera
# Processing Record 44 of Set 5 | emerald
# Processing Record 45 of Set 5 | hofn
# Processing Record 46 of Set 5 | turukhansk
# Processing Record 47 of Set 5 | melfort
# Processing Record 48 of Set 5 | bermeo
# Processing Record 49 of Set 5 | karratha
# Processing Record 50 of Set 5 | porto walter
# Processing Record 1 of Set 6 | srednekolymsk
# Processing Record 2 of Set 6 | carnarvon
# Processing Record 3 of Set 6 | sao joaquim
# Processing Record 4 of Set 6 | college
# Processing Record 5 of Set 6 | san jose
# Processing Record 6 of Set 6 | houma
# Processing Record 7 of Set 6 | sawakin
# Processing Record 8 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 6 | thunder bay
# Processing Record 10 of Set 6 | bethel
# Processing Record 11 of Set 6 | pisco
# Processing Record 12 of Set 6 | batagay-alyta
# Processing Record 13 of Set 6 | kloulklubed
# Processing Record 14 of Set 6 | cabo san lucas
# Processing Record 15 of Set 6 | bilma
# Processing Record 16 of Set 6 | naze
# Processing Record 17 of Set 6 | saint-augustin
# Processing Record 18 of Set 6 | ostrovnoy
# Processing Record 19 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 20 of Set 6 | jiazi
# Processing Record 21 of Set 6 | kibala
# Processing Record 22 of Set 6 | pilar
# Processing Record 23 of Set 6 | novaya ladoga
# Processing Record 24 of Set 6 | ciechanow
# Processing Record 25 of Set 6 | haimen
# Processing Record 26 of Set 6 | nanuque
# Processing Record 27 of Set 6 | kumluca
# Processing Record 28 of Set 6 | cherskiy
# Processing Record 29 of Set 6 | zarakes
# City not found. Skipping...
# Processing Record 30 of Set 6 | havoysund
# Processing Record 31 of Set 6 | dali
# Processing Record 32 of Set 6 | cabo rojo
# Processing Record 33 of Set 6 | athabasca
# Processing Record 34 of Set 6 | bahia blanca
# Processing Record 35 of Set 6 | alpena
# Processing Record 36 of Set 6 | bridgetown
# Processing Record 37 of Set 6 | mogadishu
# Processing Record 38 of Set 6 | caraquet
# Processing Record 39 of Set 6 | mikhaylovskoye
# Processing Record 40 of Set 6 | dien bien
# City not found. Skipping...
# Processing Record 41 of Set 6 | las tunas
# Processing Record 42 of Set 6 | lompoc
# Processing Record 43 of Set 6 | jumla
# Processing Record 44 of Set 6 | walvis bay
# Processing Record 45 of Set 6 | pevek
# Processing Record 46 of Set 6 | hidrolandia
# Processing Record 47 of Set 6 | lata
# Processing Record 48 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 6 | zlatoustovsk
# City not found. Skipping...
# Processing Record 50 of Set 6 | ketchikan
# Processing Record 1 of Set 7 | sedelnikovo
# City not found. Skipping...
# Processing Record 2 of Set 7 | bengkulu
# Processing Record 3 of Set 7 | kailua
# Processing Record 4 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 7 | snasa
# Processing Record 6 of Set 7 | saint-pierre
# Processing Record 7 of Set 7 | anju
# Processing Record 8 of Set 7 | vila franca do campo
# Processing Record 9 of Set 7 | taoudenni
# Processing Record 10 of Set 7 | malko tarnovo
# Processing Record 11 of Set 7 | daru
# Processing Record 12 of Set 7 | ancud
# Processing Record 13 of Set 7 | clyde river
# Processing Record 14 of Set 7 | mehamn
# Processing Record 15 of Set 7 | pandan
# Processing Record 16 of Set 7 | letterkenny
# Processing Record 17 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 7 | tlahualilo
# City not found. Skipping...
# Processing Record 19 of Set 7 | luganville
# Processing Record 20 of Set 7 | oranjemund
# Processing Record 21 of Set 7 | saint-denis
# Processing Record 22 of Set 7 | berlevag
# Processing Record 23 of Set 7 | seoul
# Processing Record 24 of Set 7 | ilo
# Processing Record 25 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 26 of Set 7 | brewster
# Processing Record 27 of Set 7 | yantal
# Processing Record 28 of Set 7 | lagoa
# Processing Record 29 of Set 7 | ende
# Processing Record 30 of Set 7 | fortuna
# Processing Record 31 of Set 7 | sinnamary
# Processing Record 32 of Set 7 | tiksi
# Processing Record 33 of Set 7 | faanui
# Processing Record 34 of Set 7 | chandbali
# Processing Record 35 of Set 7 | manta
# Processing Record 36 of Set 7 | altay
# Processing Record 37 of Set 7 | katangli
# Processing Record 38 of Set 7 | partapur
# Processing Record 39 of Set 7 | preobrazhenskaya
# City not found. Skipping...
# Processing Record 40 of Set 7 | kontagora
# Processing Record 41 of Set 7 | kedainiai
# Processing Record 42 of Set 7 | antofagasta
# Processing Record 43 of Set 7 | semaria
# Processing Record 44 of Set 7 | porto franco
# Processing Record 45 of Set 7 | bulaevo
# Processing Record 46 of Set 7 | minsk
# Processing Record 47 of Set 7 | vestmanna
# Processing Record 48 of Set 7 | puerto maldonado
# Processing Record 49 of Set 7 | coahuayana
# Processing Record 50 of Set 7 | manapparai
# Processing Record 1 of Set 8 | petatlan
# Processing Record 2 of Set 8 | la maddalena
# Processing Record 3 of Set 8 | chutung
# City not found. Skipping...
# Processing Record 4 of Set 8 | hella
# Processing Record 5 of Set 8 | tilichiki
# Processing Record 6 of Set 8 | saint george
# Processing Record 7 of Set 8 | arcelia
# Processing Record 8 of Set 8 | yuci
# Processing Record 9 of Set 8 | cockburn town
# Processing Record 10 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 8 | palmer
# Processing Record 12 of Set 8 | pitimbu
# Processing Record 13 of Set 8 | twin falls
# Processing Record 14 of Set 8 | tucuman
# Processing Record 15 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 8 | sikea
# City not found. Skipping...
# Processing Record 17 of Set 8 | vredendal
# Processing Record 18 of Set 8 | boueni
# Processing Record 19 of Set 8 | otane
# Processing Record 20 of Set 8 | logan lake
# Processing Record 21 of Set 8 | nukus
# Processing Record 22 of Set 8 | wukari
# Processing Record 23 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 8 | miri
# Processing Record 25 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 26 of Set 8 | nelson bay
# Processing Record 27 of Set 8 | koulikoro
# Processing Record 28 of Set 8 | margate
# Processing Record 29 of Set 8 | ixtapa
# Processing Record 30 of Set 8 | tecoanapa
# Processing Record 31 of Set 8 | iqaluit
# Processing Record 32 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 33 of Set 8 | airai
# Processing Record 34 of Set 8 | beloha
# Processing Record 35 of Set 8 | tezu
# Processing Record 36 of Set 8 | dingle
# Processing Record 37 of Set 8 | waipawa
# Processing Record 38 of Set 8 | camacha
# Processing Record 39 of Set 8 | barcelos
# Processing Record 40 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 8 | banswada
# Processing Record 42 of Set 8 | shubarkuduk
# Processing Record 43 of Set 8 | san jose de guanipa
# Processing Record 44 of Set 8 | nemuro
# Processing Record 45 of Set 8 | chifeng
# Processing Record 46 of Set 8 | micomeseng
# Processing Record 47 of Set 8 | kununurra
# Processing Record 48 of Set 8 | sosnovo-ozerskoye
# Processing Record 49 of Set 8 | spirit river
# Processing Record 50 of Set 8 | broken hill
# Processing Record 1 of Set 9 | one hundred mile house
# City not found. Skipping...
# Processing Record 2 of Set 9 | namibe
# Processing Record 3 of Set 9 | axim
# Processing Record 4 of Set 9 | puerto del rosario
# Processing Record 5 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 9 | hamilton
# Processing Record 7 of Set 9 | genoa
# Processing Record 8 of Set 9 | pottsville
# Processing Record 9 of Set 9 | orbottyan
# Processing Record 10 of Set 9 | la peca
# Processing Record 11 of Set 9 | puerto varas
# Processing Record 12 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 13 of Set 9 | birao
# Processing Record 14 of Set 9 | natchitoches
# Processing Record 15 of Set 9 | bolobo
# Processing Record 16 of Set 9 | foz do iguacu
# Processing Record 17 of Set 9 | daxian
# City not found. Skipping...
# Processing Record 18 of Set 9 | karlskrona
# Processing Record 19 of Set 9 | ostersund
# Processing Record 20 of Set 9 | uruzgan
# Processing Record 21 of Set 9 | pyay
# Processing Record 22 of Set 9 | novopokrovka
# Processing Record 23 of Set 9 | mount gambier
# Processing Record 24 of Set 9 | bambanglipuro
# Processing Record 25 of Set 9 | hauterive
# Processing Record 26 of Set 9 | ballina
# Processing Record 27 of Set 9 | bobo dioulasso
# Processing Record 28 of Set 9 | rio gallegos
# Processing Record 29 of Set 9 | kembe
# Processing Record 30 of Set 9 | tiznit
# Processing Record 31 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 9 | high level
# Processing Record 33 of Set 9 | khairpur nathan shah
# Processing Record 34 of Set 9 | agua verde
# Processing Record 35 of Set 9 | lorengau
# Processing Record 36 of Set 9 | leningradskiy
# Processing Record 37 of Set 9 | dukat
# Processing Record 38 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 39 of Set 9 | lucea
# Processing Record 40 of Set 9 | tahe
# Processing Record 41 of Set 9 | aklavik
# Processing Record 42 of Set 9 | portree
# Processing Record 43 of Set 9 | port hedland
# Processing Record 44 of Set 9 | ishigaki
# Processing Record 45 of Set 9 | dawei
# Processing Record 46 of Set 9 | qafsah
# City not found. Skipping...
# Processing Record 47 of Set 9 | alice springs
# Processing Record 48 of Set 9 | ponta delgada
# Processing Record 49 of Set 9 | shelburne
# Processing Record 50 of Set 9 | umm jarr
# City not found. Skipping...
# Processing Record 1 of Set 10 | sompeta
# Processing Record 2 of Set 10 | nirmali
# Processing Record 3 of Set 10 | mitsamiouli
# Processing Record 4 of Set 10 | gebre guracha
# Processing Record 5 of Set 10 | sao joao da barra
# Processing Record 6 of Set 10 | nome
# Processing Record 7 of Set 10 | uch
# Processing Record 8 of Set 10 | changchun
# Processing Record 9 of Set 10 | marsh harbour
# Processing Record 10 of Set 10 | gat
# Processing Record 11 of Set 10 | anapolis
# Processing Record 12 of Set 10 | xuddur
# Processing Record 13 of Set 10 | matinha
# Processing Record 14 of Set 10 | naryan-mar
# Processing Record 15 of Set 10 | hirara
# Processing Record 16 of Set 10 | pathanamthitta
# Processing Record 17 of Set 10 | cayenne
# Processing Record 18 of Set 10 | sibu
# Processing Record 19 of Set 10 | broome
# Processing Record 20 of Set 10 | husavik
# Processing Record 21 of Set 10 | chokurdakh
# Processing Record 22 of Set 10 | aksarka
# Processing Record 23 of Set 10 | grafton
# Processing Record 24 of Set 10 | normandin
# Processing Record 25 of Set 10 | grindavik
# Processing Record 26 of Set 10 | necochea
# Processing Record 27 of Set 10 | lingao
# Processing Record 28 of Set 10 | bentiu
# Processing Record 29 of Set 10 | villarrica
# Processing Record 30 of Set 10 | sorkjosen
# Processing Record 31 of Set 10 | xiongshi
# City not found. Skipping...
# Processing Record 32 of Set 10 | soyo
# Processing Record 33 of Set 10 | pendleton
# Processing Record 34 of Set 10 | acapulco
# Processing Record 35 of Set 10 | san cristobal
# Processing Record 36 of Set 10 | kavaratti
# Processing Record 37 of Set 10 | villanueva de cordoba
# Processing Record 38 of Set 10 | tupelo
# Processing Record 39 of Set 10 | lokosovo
# Processing Record 40 of Set 10 | bonavista
# Processing Record 41 of Set 10 | balclutha
# Processing Record 42 of Set 10 | bubaque
# Processing Record 43 of Set 10 | saint-michel-des-saints
# Processing Record 44 of Set 10 | rupert
# Processing Record 45 of Set 10 | kisangani
# Processing Record 46 of Set 10 | kataysk
# Processing Record 47 of Set 10 | saldanha
# Processing Record 48 of Set 10 | kavarskas
# Processing Record 49 of Set 10 | ericeira
# Processing Record 50 of Set 10 | mackay
# Processing Record 1 of Set 11 | laguna
# Processing Record 2 of Set 11 | bejar
# Processing Record 3 of Set 11 | de aar
# Processing Record 4 of Set 11 | lukulu
# Processing Record 5 of Set 11 | lasa
# Processing Record 6 of Set 11 | bassar
# Processing Record 7 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 11 | sungairaya
# Processing Record 9 of Set 11 | vitoria da conquista
# Processing Record 10 of Set 11 | biak
# Processing Record 11 of Set 11 | batticaloa
# Processing Record 12 of Set 11 | abu dhabi
# Processing Record 13 of Set 11 | guhagar
# Processing Record 14 of Set 11 | araouane
# Processing Record 15 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 11 | luderitz
# Processing Record 17 of Set 11 | mawlaik
# Processing Record 18 of Set 11 | penzance
# Processing Record 19 of Set 11 | chekhov
# Processing Record 20 of Set 11 | paka
# Processing Record 21 of Set 11 | santa cruz
# Processing Record 22 of Set 11 | revda
# Processing Record 23 of Set 11 | bastia
# Processing Record 24 of Set 11 | desna
# Processing Record 25 of Set 11 | eltham
# Processing Record 26 of Set 11 | port augusta
# Processing Record 27 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 11 | valparaiso
# Processing Record 29 of Set 11 | bintulu
# Processing Record 30 of Set 11 | sarankhola
# Processing Record 31 of Set 11 | stanovoye
# Processing Record 32 of Set 11 | itarantim
# Processing Record 33 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 34 of Set 11 | huarmey
# Processing Record 35 of Set 11 | diffa
# Processing Record 36 of Set 11 | vardo
# Processing Record 37 of Set 11 | tenenkou
# Processing Record 38 of Set 11 | aporawan
# City not found. Skipping...
# Processing Record 39 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 11 | pithoragarh
# Processing Record 41 of Set 11 | kankon
# Processing Record 42 of Set 11 | macaboboni
# City not found. Skipping...
# Processing Record 43 of Set 11 | marovoay
# Processing Record 44 of Set 11 | kokoda
# Processing Record 45 of Set 11 | villa carlos paz
# Processing Record 46 of Set 11 | bartica
# Processing Record 47 of Set 11 | inirida
# Processing Record 48 of Set 11 | rio grande
# Processing Record 49 of Set 11 | archidona
# Processing Record 50 of Set 11 | urdzhar
# City not found. Skipping...
# Processing Record 1 of Set 12 | chicama
# Processing Record 2 of Set 12 | bay roberts
# Processing Record 3 of Set 12 | viesca
# Processing Record 4 of Set 12 | charleston
# Processing Record 5 of Set 12 | carauari
# Processing Record 6 of Set 12 | deputatskiy
# Processing Record 7 of Set 12 | mirina
# City not found. Skipping...
# Processing Record 8 of Set 12 | shenjiamen
# Processing Record 9 of Set 12 | virginia beach
# Processing Record 10 of Set 12 | raudeberg
# Processing Record 11 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 12 of Set 12 | omaruru
# Processing Record 13 of Set 12 | qazvin
# Processing Record 14 of Set 12 | belmonte
# Processing Record 15 of Set 12 | jacqueville
# Processing Record 16 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 17 of Set 12 | torres
# Processing Record 18 of Set 12 | weligama
# Processing Record 19 of Set 12 | inverness
# Processing Record 20 of Set 12 | zhengjiatun
# Processing Record 21 of Set 12 | san antonio
# Processing Record 22 of Set 12 | ndiekro
# City not found. Skipping...
# Processing Record 23 of Set 12 | grand bank
# Processing Record 24 of Set 12 | konch
# Processing Record 25 of Set 12 | igrim
# Processing Record 26 of Set 12 | uong bi
# Processing Record 27 of Set 12 | virpur
# Processing Record 28 of Set 12 | ugoofaaru
# Processing Record 29 of Set 12 | dekernes
# Processing Record 30 of Set 12 | mansehra
# Processing Record 31 of Set 12 | pochutla
# Processing Record 32 of Set 12 | sisimiut
# Processing Record 33 of Set 12 | portpatrick
# City not found. Skipping...
# Processing Record 34 of Set 12 | severodvinsk
# Processing Record 35 of Set 12 | imbituba
# Processing Record 36 of Set 12 | gornopravdinsk
# Processing Record 37 of Set 12 | sagaing
# Processing Record 38 of Set 12 | porto belo
# Processing Record 39 of Set 12 | barao de melgaco
# Processing Record 40 of Set 12 | canaries
# Processing Record 41 of Set 12 | carnot
# Processing Record 42 of Set 12 | mehran
# Processing Record 43 of Set 12 | santa lucia
# Processing Record 44 of Set 12 | sfantu gheorghe
# Processing Record 45 of Set 12 | moulins
# Processing Record 46 of Set 12 | mbini
# Processing Record 47 of Set 12 | vila velha
# Processing Record 48 of Set 12 | katsuura
# Processing Record 49 of Set 12 | rapid valley
# Processing Record 50 of Set 12 | brigantine
# Processing Record 1 of Set 13 | sorland
# Processing Record 2 of Set 13 | kavieng
# Processing Record 3 of Set 13 | alta floresta
# Processing Record 4 of Set 13 | kiama
# Processing Record 5 of Set 13 | rumoi
# Processing Record 6 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 7 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 8 of Set 13 | bacolod
# Processing Record 9 of Set 13 | isiro
# Processing Record 10 of Set 13 | jambi
# Processing Record 11 of Set 13 | igarka
# Processing Record 12 of Set 13 | ahipara
# Processing Record 13 of Set 13 | tashtyp
# Processing Record 14 of Set 13 | tura
# Processing Record 15 of Set 13 | coihaique
# Processing Record 16 of Set 13 | kingman
# Processing Record 17 of Set 13 | kindu
# Processing Record 18 of Set 13 | mulchen
# Processing Record 19 of Set 13 | ust-omchug
# Processing Record 20 of Set 13 | mazagao
# Processing Record 21 of Set 13 | margherita
# Processing Record 22 of Set 13 | chachapoyas
# Processing Record 23 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 13 | dehloran
# Processing Record 25 of Set 13 | labuhan
# Processing Record 26 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 13 | salalah
# Processing Record 28 of Set 13 | yumen
# Processing Record 29 of Set 13 | mohan
# Processing Record 30 of Set 13 | yerofey pavlovich
# Processing Record 31 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 13 | temba
# Processing Record 33 of Set 13 | gogrial
# Processing Record 34 of Set 13 | nuuk
# Processing Record 35 of Set 13 | lulea
# Processing Record 36 of Set 13 | magistralnyy
# Processing Record 37 of Set 13 | port-gentil
# Processing Record 38 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 13 | baft
# Processing Record 40 of Set 13 | zhigansk
# Processing Record 41 of Set 13 | kaeo
# Processing Record 42 of Set 13 | quzhou
# Processing Record 43 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 44 of Set 13 | kirakira
# Processing Record 45 of Set 13 | douglas
# Processing Record 46 of Set 13 | tanout
# Processing Record 47 of Set 13 | roald
# Processing Record 48 of Set 13 | mayo
# Processing Record 49 of Set 13 | aktyubinskiy
# Processing Record 50 of Set 13 | manbij
# Processing Record 1 of Set 14 | biltine
# Processing Record 2 of Set 14 | cibitoke
# Processing Record 3 of Set 14 | barberton
# Processing Record 4 of Set 14 | asau
# Processing Record 5 of Set 14 | nueva loja
# Processing Record 6 of Set 14 | vangaindrano
# Processing Record 7 of Set 14 | fairbanks
# Processing Record 8 of Set 14 | abilene
# Processing Record 9 of Set 14 | manica
# Processing Record 10 of Set 14 | angoram
# Processing Record 11 of Set 14 | saint simons
# Processing Record 12 of Set 14 | zabol
# Processing Record 13 of Set 14 | mandalgovi
# Processing Record 14 of Set 14 | atambua
# Processing Record 15 of Set 14 | iquique
# Processing Record 16 of Set 14 | baykit
# Processing Record 17 of Set 14 | narasannapeta
# Processing Record 18 of Set 14 | chavakkad
# Processing Record 19 of Set 14 | severo-yeniseyskiy
# Processing Record 20 of Set 14 | atasu
# Processing Record 21 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 22 of Set 14 | mapiri
# Processing Record 23 of Set 14 | beaverlodge
# Processing Record 24 of Set 14 | abensberg
# Processing Record 25 of Set 14 | nushki
# Processing Record 26 of Set 14 | ode
# Processing Record 27 of Set 14 | qaqortoq
# Processing Record 28 of Set 14 | glomfjord
# Processing Record 29 of Set 14 | mildura
# Processing Record 30 of Set 14 | senmonorom
# City not found. Skipping...
# Processing Record 31 of Set 14 | sobolevo
# Processing Record 32 of Set 14 | malgrat de mar
# Processing Record 33 of Set 14 | westport
# Processing Record 34 of Set 14 | henties bay
# Processing Record 35 of Set 14 | poya
# Processing Record 36 of Set 14 | tanabe
# Processing Record 37 of Set 14 | hambantota
# Processing Record 38 of Set 14 | krasnogvardeyskoye
# Processing Record 39 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 40 of Set 14 | burns lake
# Processing Record 41 of Set 14 | mecca
# Processing Record 42 of Set 14 | shimanovsk
# Processing Record 43 of Set 14 | katherine
# Processing Record 44 of Set 14 | mana
# Processing Record 45 of Set 14 | otaru
# Processing Record 46 of Set 14 | havre-saint-pierre
# Processing Record 47 of Set 14 | minador do negrao
# Processing Record 48 of Set 14 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 49 of Set 14 | sibolga
# Processing Record 50 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 15 | kaura namoda
# Processing Record 2 of Set 15 | atar
# Processing Record 3 of Set 15 | richards bay
# Processing Record 4 of Set 15 | cabatuan
# Processing Record 5 of Set 15 | gikongoro
# Processing Record 6 of Set 15 | umea
# Processing Record 7 of Set 15 | bhum
# Processing Record 8 of Set 15 | anzio
# Processing Record 9 of Set 15 | nola
# Processing Record 10 of Set 15 | itamaraju
# Processing Record 11 of Set 15 | piney green
# Processing Record 12 of Set 15 | kenai
# Processing Record 13 of Set 15 | peace river
# Processing Record 14 of Set 15 | mabaruma
# Processing Record 15 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 15 | morgan city
# Processing Record 17 of Set 15 | vilhena
# Processing Record 18 of Set 15 | arman
# Processing Record 19 of Set 15 | urucui
# Processing Record 20 of Set 15 | cabra
# Processing Record 21 of Set 15 | kumba
# Processing Record 22 of Set 15 | manuk mangkaw
# Processing Record 23 of Set 15 | boundiali
# Processing Record 24 of Set 15 | camalu
# Processing Record 25 of Set 15 | san pedro de macoris
# Processing Record 26 of Set 15 | collie
# Processing Record 27 of Set 15 | waingapu
# Processing Record 28 of Set 15 | wanning
# Processing Record 29 of Set 15 | dunda
# Processing Record 30 of Set 15 | riverton
# Processing Record 31 of Set 15 | manggar
# Processing Record 32 of Set 15 | quatre cocos
# Processing Record 33 of Set 15 | harbour breton
# Processing Record 34 of Set 15 | jeremie
# Processing Record 35 of Set 15 | mount isa
# Processing Record 36 of Set 15 | diamantino
# Processing Record 37 of Set 15 | salinopolis
# Processing Record 38 of Set 15 | muzaffarabad
# Processing Record 39 of Set 15 | cedar city
# Processing Record 40 of Set 15 | ha tinh
# Processing Record 41 of Set 15 | san miguel
# Processing Record 42 of Set 15 | tres arroyos
# Processing Record 43 of Set 15 | madingou
# Processing Record 44 of Set 15 | riohacha
# Processing Record 45 of Set 15 | armacao dos buzios
# City not found. Skipping...
# Processing Record 46 of Set 15 | itarema
# Processing Record 47 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 15 | muzhi
# Processing Record 49 of Set 15 | yar-sale
# Processing Record 50 of Set 15 | mackenzie
# Processing Record 1 of Set 16 | bosobolo
# Processing Record 2 of Set 16 | porteirinha
# Processing Record 3 of Set 16 | octeville
# Processing Record 4 of Set 16 | cortes
# Processing Record 5 of Set 16 | aksha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 681

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Dikson  73.5069   80.5464     31.12        69         100
# 1  Ponta Do Sol  32.6667  -17.1000     75.70        86          92
# 2  Guayaramerin -10.8368  -65.3614     93.25        49          40
# 3   Port Alfred -33.5906   26.8910     63.18        90         100
# 4         Bluff -46.6000  168.3333     36.81        69          89
# 5   East London -33.0153   27.9116     66.60        79          86
# 6      La Ronge  55.1001 -105.2842     37.65        56          40
# 7        Pangai -19.8000 -174.3500     75.31        94          75
# 8    Bredasdorp -34.5322   20.0403     56.14        72          15
# 9     Hithadhoo  -0.6000   73.0833     82.74        74          94
#
#    Wind Speed Country Current Description
# 0        1.36      RU     overcast clouds
# 1        1.30      PT     overcast clouds
# 2       12.66      BO    scattered clouds
# 3        3.00      ZA     overcast clouds
# 4       23.06      NZ     overcast clouds
# 5        9.22      ZA     overcast clouds
# 6       10.36      CA    scattered clouds
# 7        6.91      TO       broken clouds
# 8        7.83      ZA          few clouds
# 9       17.40      MV       moderate rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Dikson      RU  73.5069   80.5464     31.12        69         100
# 1  Ponta Do Sol      PT  32.6667  -17.1000     75.70        86          92
# 2  Guayaramerin      BO -10.8368  -65.3614     93.25        49          40
# 3   Port Alfred      ZA -33.5906   26.8910     63.18        90         100
# 4         Bluff      NZ -46.6000  168.3333     36.81        69          89
# 5   East London      ZA -33.0153   27.9116     66.60        79          86
# 6      La Ronge      CA  55.1001 -105.2842     37.65        56          40
# 7        Pangai      TO -19.8000 -174.3500     75.31        94          75
# 8    Bredasdorp      ZA -34.5322   20.0403     56.14        72          15
# 9     Hithadhoo      MV  -0.6000   73.0833     82.74        74          94
#
#    Wind Speed Current Description
# 0        1.36     overcast clouds
# 1        1.30     overcast clouds
# 2       12.66    scattered clouds
# 3        3.00     overcast clouds
# 4       23.06     overcast clouds
# 5        9.22     overcast clouds
# 6       10.36    scattered clouds
# 7        6.91       broken clouds
# 8        7.83          few clouds
# 9       17.40       moderate rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
